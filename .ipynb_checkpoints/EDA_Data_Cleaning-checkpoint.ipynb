# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.style.use('ggplot')
plt.rcParams.update({'font.size': 8})

# %% [markdown]
# # I. LOAD DATA

# %%
train = pd.read_csv('./Data/train.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.shape[0]
# Out:
# 1460

# %%
train.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
#list(train)

# %% [markdown]
# ## Create some new variables

# %%
# Create New Numerical Variables
train['AgeWhenSold'] = train['YrSold'] - train['YearBuilt']
train['YrsSinceRemodel'] = train['YrSold'] - train['YearRemodAdd']

# %%
# Ensure these variabes are categorical
train['MSSubClass'] = train['MSSubClass'].astype(str)
train['OverallQual'] = train['OverallQual'].astype(str)
train['OverallCond'] = train['OverallCond'].astype(str)

train['MoSold'] = train['MoSold'].astype(str)
train['YrSold'] = train['YrSold'].astype(str)
train['YearBuilt'] = train['YearBuilt'].astype(str)
      
train['YearRemodAdd'] = train['YearRemodAdd'].astype(str)
train['GarageYrBlt'] = train['GarageYrBlt'].astype(str)

# %%
train.loc[(train['GarageYrBlt']=='nan'),'GarageYrBlt']= np.nan

# %% [markdown]
# # II. EXPLORATORY DATA ANALYSIS & VISUALIZATIONS

# %% [markdown]
# ## A. The Numeric Variables

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
num_train = train.select_dtypes(include=numerics)
numlist = list(num_train)
print(len(numlist),' numeric variables')
print(numlist)
# Out:
# 32  numeric variables
# ['Id', 'LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice', 'AgeWhenSold', 'YrsSinceRemodel']

# %%
num_train.describe()
# Out:
#                 Id  LotFrontage        LotArea   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1201.000000    1460.000000  1452.000000  1460.000000
# mean    730.500000    70.049958   10516.828082   103.685262   443.639726
# std     421.610009    24.284752    9981.264932   181.066207   456.098091
# min       1.000000    21.000000    1300.000000     0.000000     0.000000
# 25%     365.750000    59.000000    7553.500000     0.000000     0.000000
# 50%     730.500000    69.000000    9478.500000     0.000000   383.500000
# 75%    1095.250000    80.000000   11601.500000   166.000000   712.250000
# max    1460.000000   313.000000  215245.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466  ...
# std     161.319273   441.866955   438.705324   386.587738   436.528436  ...
# ...

# %% [markdown]
# ### Look at the Output/Dependent Variable (Y)

# %%
# The Distribution of the OUTPUT/DEPENDENT variable

fig, axs = plt.subplots(1,2)
fig.suptitle('SalePrice')
axs[1].boxplot(train['SalePrice'],vert=False)
axs[1].tick_params(axis='x', rotation = 45)
axs[0].hist(train['SalePrice'])
axs[0].tick_params(axis='x', rotation=45)

print('25th percentile:',train['SalePrice'].quantile(.25))
print('50th percentile:',train['SalePrice'].median())
print('75th percentile:',train['SalePrice'].quantile(.75))
print('# of Missing Rows: ', train['SalePrice'].isna().sum(), 
    ' out of ',len(num_train['SalePrice']))
# Out:
# 25th percentile: 129975.0
# 50th percentile: 163000.0
# 75th percentile: 214000.0
# # of Missing Rows:  0  out of  1460

# %% [markdown]
# ### The Independent Variable (Xs)

# %%
#for nvar in numlist:
#    fig, axs = plt.subplots(1,2)
#    fig.suptitle(nvar)
    
#    # Histogram
#    axs[1].hist(train[nvar])
#    axs[1].tick_params(axis='x', rotation=45)
#    axs[1].set_ylabel('Count')
#    axs[1].set_xlabel(nvar)
    
#    # Which indices have z-scores > 4
#    zvals = stats.zscore(train[nvar])
#    indx = np.where(abs(zvals) > 4)

#    # Scatter
#    axs[0].scatter(train[nvar],num_train['SalePrice'])
#    axs[0].scatter(train.loc[indx,nvar],train.loc[indx,'SalePrice'])

#    axs[0].tick_params(axis='x', rotation=45)
#    axs[0].set_ylabel('SalePrice')
#    axs[0].set_xlabel(nvar)

# %%
# Correlations between Output variable and other numerical variables
correlations = num_train.corr()
# print(correlations['SalePrice'])
ycorr = correlations['SalePrice']
ycorr[np.abs(ycorr)>0.4]
# Out:
# MasVnrArea         0.477493
# TotalBsmtSF        0.613581
# 1stFlrSF           0.605852
# GrLivArea          0.708624
# FullBath           0.560664
# TotRmsAbvGrd       0.533723
# Fireplaces         0.466929
# GarageCars         0.640409
# GarageArea         0.623431
# SalePrice          1.000000
# AgeWhenSold       -0.523350
# YrsSinceRemodel   -0.509079
# Name: SalePrice, dtype: float64

# %%
# manually created this, figure out how to do it automatically above
hcorr_list = ['AgeWhenSold','YrsSinceRemodel',
              'MasVnrArea','TotalBsmtSF', 
             '1stFlrSF','GrLivArea','FullBath',
             'TotRmsAbvGrd','Fireplaces',
             'GarageCars','GarageArea']

# %%
for nvar in hcorr_list:
    fig, axs = plt.subplots(1,2)
    fig.suptitle(nvar)
    
    # Histogram
    axs[1].hist(train[nvar],color='b')
    axs[1].tick_params(axis='x', rotation=45)
    axs[1].set_ylabel('Count')
    axs[1].set_xlabel(nvar)
    
    # Which indices have z-scores > 4
    zvals = stats.zscore(train[nvar])
    indx = np.where(abs(zvals) > 4)
    print('The Outliers (?)')
    print(nvar,indx)
    
    # Scatter
    axs[0].scatter(train[nvar],train['SalePrice'],color='b')
    axs[0].scatter(train.loc[indx,nvar],train.loc[indx,'SalePrice'])

    axs[0].tick_params(axis='x', rotation=45)
    axs[0].set_ylabel('SalePrice')
    axs[0].set_xlabel(nvar)
# Out:
# The Outliers (?)
# AgeWhenSold (array([], dtype=int64),)
# The Outliers (?)
# YrsSinceRemodel (array([], dtype=int64),)
# The Outliers (?)
# MasVnrArea (array([], dtype=int64),)
# The Outliers (?)
# TotalBsmtSF (array([ 332,  440,  496,  523, 1298]),)
# The Outliers (?)
# 1stFlrSF (array([ 496,  523, 1024, 1298]),)
# The Outliers (?)
# GrLivArea (array([ 523,  691, 1169, 1182, 1298]),)
# The Outliers (?)
# FullBath (array([], dtype=int64),)
# The Outliers (?)
# TotRmsAbvGrd (array([635]),)
# The Outliers (?)
# Fireplaces (array([], dtype=int64),)
# The Outliers (?)
# GarageCars (array([], dtype=int64),)
# The Outliers (?)
# GarageArea (array([ 581, 1190, 1298]),)

# %% [markdown]
# ## B. The Categorical Variables

# %%
cattypes = ['O']
cat_train = train.select_dtypes(include=cattypes)
catlist = list(cat_train)
print(len(catlist),' categorical variables')
catlist
# Out:
# 51  categorical variables
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition']

# %%
for cvar in catlist:   
    plt.figure(figsize = (15,8))
    
    # ordering by median
    temp = train.groupby([cvar])['SalePrice'].median().sort_values(ascending=False).reset_index()
    
    # Boxplot
    sns.boxplot(x=train[cvar], 
                   y=train['SalePrice'],
               order = list(temp[cvar]))
    #ax.tick_params(axis='x', rotation=45)
    #ax.set_ylabel('Sale Price')
    #ax.set_xlabel(cvar)
# Out:
# <ipython-input-25-6f287b13dca2>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize = (15,8))

# %% [markdown]
# # III. PREPROCESSING - Preparation for Model Training

# %% [markdown]
# ## 3A. Imputation - Numerical Variables

# %%
# How many Missing Values?
num_train.isna().sum()
# Out:
# Id                   0
# LotFrontage        259
# LotArea              0
# MasVnrArea           8
# BsmtFinSF1           0
# BsmtFinSF2           0
# BsmtUnfSF            0
# TotalBsmtSF          0
# 1stFlrSF             0
# 2ndFlrSF             0
# LowQualFinSF         0
# GrLivArea            0
# BsmtFullBath         0
# BsmtHalfBath         0
# FullBath             0
# HalfBath             0
# BedroomAbvGr         0
# KitchenAbvGr         0
# TotRmsAbvGrd         0
# Fireplaces           0
# GarageCars           0
# GarageArea           0
# WoodDeckSF           0
# OpenPorchSF          0
# EnclosedPorch        0
# 3SsnPorch            0
# ScreenPorch          0
# PoolArea             0
# MiscVal              0
# SalePrice            0
# AgeWhenSold          0
# YrsSinceRemodel      0
# dtype: int64

# %% [markdown]
# ## * MasVnrArea

# %%
train['MasVnrArea'].isnull().sum()
# Out:
# 8

# %%
# For these 'MasVnrArea' = nan, what'MasVnrType's do we have?
train[train['MasVnrArea'].isnull()]['MasVnrType'].unique()
# Out:
# array([nan], dtype=object)

# %%
train[(train['MasVnrArea'].isnull())]['MasVnrType']
# Out:
# 234     NaN
# 529     NaN
# 650     NaN
# 936     NaN
# 973     NaN
# 977     NaN
# 1243    NaN
# 1278    NaN
# Name: MasVnrType, dtype: object

# %%
# What are the other types?
train['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn', nan], dtype=object)

# %%
# ACTION: Let's change the MasVnrType to 'None', for the MasVnrArea = NaN rows 
train.loc[(train['MasVnrArea'].isnull()),'MasVnrType']='None'

# ACTION: Let's change the MasVnrArea to 0.0, for the MasVnrArea = NaN rows 
train.loc[(train['MasVnrArea'].isnull()),'MasVnrArea']= 0.0

# %%
train['MasVnrType'].unique()
# Out:
# array(['BrkFace', 'None', 'Stone', 'BrkCmn'], dtype=object)

# %%
print('MasVnrArea = nan are gone')
train['MasVnrArea'].isnull().sum()
# Out:
# MasVnrArea = nan are gone
# 0

# %% [markdown]
# #### Another Discrepancy
# - Here you see that some of the 'MasVnrType' == 'None' rows, have 'MasVnrArea' that are not equal to 0.0

# %%
print('Another issue... This does NOT make sense:')
train[(train['MasVnrType']=='None') & (train['MasVnrArea']!=0)]['MasVnrArea']
# Out:
# Another issue... This does NOT make sense:
# 624     288.0
# 773       1.0
# 1230      1.0
# 1300    344.0
# 1334    312.0
# Name: MasVnrArea, dtype: float64

# %%
# ACTION: Let's change these rows' MasVnrArea to 0.0
# train.loc[((train['MasVnrType']=='None') & (train['MasVnrArea']!=0)),'MasVnrArea']= 0.0

# OR 
# remove these rows????? 
#train = train.drop(labels=[624,773,1230,1300,1334], axis=0)

# %%
train[(train['MasVnrType']=='None') & (train['MasVnrArea']!=0)]['MasVnrArea']
# Out:
# 624     288.0
# 773       1.0
# 1230      1.0
# 1300    344.0
# 1334    312.0
# Name: MasVnrArea, dtype: float64

# %% [markdown]
# ## * LotFrontage

# %%
train['LotFrontage'].isnull().sum()
# Out:
# 259

# %%
# Checking the LotConfig values
train[train['LotFrontage'].isnull()]['LotConfig'].unique()
# Out:
# array(['Corner', 'Inside', 'CulDSac', 'FR2'], dtype=object)

# %%
# ACTION: Let's change the LotFrontage to 0.0, for the LotFrontage = NaN rows 
train.loc[(train['LotFrontage'].isnull()),'LotFrontage']= 0.0

# %%
train['LotFrontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Zeros

# %%
# Count number of zeros in all columns of Dataframe
for column_name in num_train.columns:
    column = num_train[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    if count != 0: 
        print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  MasVnrArea  is :  861
# Count of zeros in column  BsmtFinSF1  is :  467
# Count of zeros in column  BsmtFinSF2  is :  1293
# Count of zeros in column  BsmtUnfSF  is :  118
# Count of zeros in column  TotalBsmtSF  is :  37
# Count of zeros in column  2ndFlrSF  is :  829
# Count of zeros in column  LowQualFinSF  is :  1434
# Count of zeros in column  BsmtFullBath  is :  856
# Count of zeros in column  BsmtHalfBath  is :  1378
# Count of zeros in column  FullBath  is :  9
# Count of zeros in column  HalfBath  is :  913
# Count of zeros in column  BedroomAbvGr  is :  6
# Count of zeros in column  KitchenAbvGr  is :  1
# Count of zeros in column  Fireplaces  is :  690
# Count of zeros in column  GarageCars  is :  81
# Count of zeros in column  GarageArea  is :  81
# Count of zeros in column  WoodDeckSF  is :  761
# Count of zeros in column  OpenPorchSF  is :  656
# Count of zeros in column  EnclosedPorch  is :  1252
# ...

# %%
print('Zeros could be reasonable, come back here later')
# Out:
# Zeros could be reasonable, come back here later

# %% [markdown]
# ## 3B. Imputation - Categorica Variables

# %%
# How many Missing Values?
cat_train.isna().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functional          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
cat_miss = list(cat_train.columns[np.where(cat_train.isna().sum() > 0)])
list(cat_miss)
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
for cvar in cat_miss:
    print(cvar, train[cvar].unique())
# Out:
# Alley [nan 'Grvl' 'Pave']
# MasVnrType ['BrkFace' 'None' 'Stone' 'BrkCmn']
# BsmtQual ['Gd' 'TA' 'Ex' nan 'Fa']
# BsmtCond ['TA' 'Gd' nan 'Fa' 'Po']
# BsmtExposure ['No' 'Gd' 'Mn' 'Av' nan]
# BsmtFinType1 ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
# BsmtFinType2 ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Electrical ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
# FireplaceQu [nan 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# GarageType ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# GarageYrBlt ['2003.0' '1976.0' '2001.0' '1998.0' '2000.0' '1993.0' '2004.0' '1973.0'
#  '1931.0' '1939.0' '1965.0' '2005.0' '1962.0' '2006.0' '1960.0' '1991.0'
#  '1970.0' '1967.0' '1958.0' '1930.0' '2002.0' '1968.0' '2007.0' '2008.0'
#  '1957.0' '1920.0' '1966.0' '1959.0' '1995.0' '1954.0' '1953.0' nan
#  '1983.0' '1977.0' '1997.0' '1985.0' '1963.0' '1981.0' '1964.0' '1999.0'
#  '1935.0' '1990.0' '1945.0' '1987.0' '1989.0' '1915.0' '1956.0' '1948.0'
# ...

# %% [markdown]
# ### Basement Analysis

# %%
bsmt_1 = np.where(train['BsmtQual'].isna())
bsmt_2 = np.where(train['BsmtCond'].isna())
bsmt_3 = np.where(train['BsmtExposure'].isna())
bsmt_4 = np.where(train['BsmtFinType1'].isna())

# %%
all_NoBsmt_rows = np.concatenate((bsmt_1, bsmt_2, bsmt_3, bsmt_4), axis=None)
print(all_NoBsmt_rows)
# Out:
# [  17   39   90  102  156  182  259  342  362  371  392  520  532  533
#   553  646  705  736  749  778  868  894  897  984 1000 1011 1035 1045
#  1048 1049 1090 1179 1216 1218 1232 1321 1412   17   39   90  102  156
#   182  259  342  362  371  392  520  532  533  553  646  705  736  749
#   778  868  894  897  984 1000 1011 1035 1045 1048 1049 1090 1179 1216
#  1218 1232 1321 1412   17   39   90  102  156  182  259  342  362  371
#   392  520  532  533  553  646  705  736  749  778  868  894  897  948
#   984 1000 1011 1035 1045 1048 1049 1090 1179 1216 1218 1232 1321 1412
#    17   39   90  102  156  182  259  342  362  371  392  520  532  533
#   553  646  705  736  749  778  868  894  897  984 1000 1011 1035 1045
#  1048 1049 1090 1179 1216 1218 1232 1321 1412]

# %%
No_Bsmt_rows = np.unique(all_NoBsmt_rows)
print(No_Bsmt_rows)
# Out:
# [  17   39   90  102  156  182  259  342  362  371  392  520  532  533
#   553  646  705  736  749  778  868  894  897  948  984 1000 1011 1035
#  1045 1048 1049 1090 1179 1216 1218 1232 1321 1412]

# %%
bsmt_cvars = ['BsmtQual',
             'BsmtCond', 
             'BsmtExposure', 
             'BsmtFinType1']

for bcvar in bsmt_cvars:
    
    print(bcvar,
          No_Bsmt_rows[np.where(train.loc[No_Bsmt_rows,bcvar].notna())],
          train.loc[No_Bsmt_rows,bcvar].unique())
# Out:
# BsmtQual [948] [nan 'Gd']
# BsmtCond [948] [nan 'TA']
# BsmtExposure [] [nan]
# BsmtFinType1 [948] [nan 'Unf']

# %%
bsmt_nvars = ['BsmtFinSF1', 
             'BsmtFinSF2', 
             'BsmtUnfSF', 
             'TotalBsmtSF', 
             'BsmtFullBath', 
             'BsmtHalfBath']     

for nvar in bsmt_nvars:
    fig, axs = plt.subplots(1,2)
    fig.suptitle(nvar)
    
    # Histogram
    axs[1].hist(train[nvar],color='b')
    axs[1].tick_params(axis='x', rotation=45)
    axs[1].set_ylabel('Count')
    axs[1].set_xlabel(nvar)
    
    # Scatter
    axs[0].scatter(train[nvar],train['SalePrice'],color='b')
    axs[0].scatter(train.loc[No_Bsmt_rows,nvar],train.loc[No_Bsmt_rows,'SalePrice'])

    print(nvar, 'indices > 0', No_Bsmt_rows[np.where(train.loc[No_Bsmt_rows, nvar]>0)])
    
    axs[0].tick_params(axis='x', rotation=45)
    axs[0].set_ylabel('SalePrice')
    axs[0].set_xlabel(nvar)
# Out:
# BsmtFinSF1 indices > 0 []
# BsmtFinSF2 indices > 0 []
# BsmtUnfSF indices > 0 [948]
# TotalBsmtSF indices > 0 [948]
# BsmtFullBath indices > 0 []
# BsmtHalfBath indices > 0 []

# %%
print('Hmmm. Could be that BsmtExposure should be No, mislabeled?')
print(train.loc[948,['BsmtQual',
             'BsmtCond', 
             'BsmtExposure', 
             'BsmtFinType1',
             'BsmtFinSF1', 
             'BsmtFinSF2', 
             'BsmtUnfSF', 
             'TotalBsmtSF', 
             'BsmtFullBath', 
             'BsmtHalfBath']])
# Out:
# Hmmm. Could be that BsmtExposure should be No, mislabeled?
# BsmtQual         Gd
# BsmtCond         TA
# BsmtExposure    NaN
# BsmtFinType1    Unf
# BsmtFinSF1        0
# BsmtFinSF2        0
# BsmtUnfSF       936
# TotalBsmtSF     936
# BsmtFullBath      0
# BsmtHalfBath      0
# Name: 948, dtype: object

# %%
# remove this row ???? 
# Does this index make sense???? COME BACK HERE
# train = train.drop(labels=[948], axis=0)

# %% [markdown]
# ### Garage Analysis

# %%
garg_1 = np.where(train['GarageType'].isna())
garg_2 = np.where(train['GarageFinish'].isna())
garg_3 = np.where(train['GarageQual'].isna())
garg_4 = np.where(train['GarageCond'].isna())
garg_5 = np.where(train['GarageYrBlt'].isna())

# %%
all_NoGarg_rows = np.concatenate((garg_1, garg_2, garg_3, garg_4, garg_5), axis=None)
# print(all_NoGarg_rows)

# %%
No_Garg_rows = np.unique(all_NoGarg_rows)
print(No_Garg_rows)
# Out:
# [  39   48   78   88   89   99  108  125  127  140  148  155  163  165
#   198  210  241  250  287  291  307  375  386  393  431  434  441  464
#   495  520  528  533  535  562  582  613  614  620  635  636  638  649
#   705  710  738  750  784  826  843  921  942  954  960  968  970  976
#  1009 1011 1030 1038 1096 1123 1131 1137 1143 1173 1179 1218 1219 1234
#  1257 1283 1323 1325 1326 1337 1349 1407 1449 1450 1453]

# %%
garg_cvars = ['GarageType',
             'GarageFinish', 
             'GarageQual', 
             'GarageCond',
             'GarageYrBlt']

for gcvar in garg_cvars:
    
    print(gcvar,
          No_Garg_rows[np.where(train.loc[No_Garg_rows,gcvar].notna())],
          train.loc[No_Garg_rows,gcvar].unique())
# Out:
# GarageType [] [nan]
# GarageFinish [] [nan]
# GarageQual [] [nan]
# GarageCond [] [nan]
# GarageYrBlt [] [nan]

# %%
garg_nvars = ['GarageCars', 
             'GarageArea']     

for nvar in garg_nvars:
    fig, axs = plt.subplots(1,2)
    fig.suptitle(nvar)
    
    # Histogram
    axs[1].hist(train[nvar],color='b')
    axs[1].tick_params(axis='x', rotation=45)
    axs[1].set_ylabel('Count')
    axs[1].set_xlabel(nvar)
    
    # Scatter
    axs[0].scatter(train[nvar],train['SalePrice'],color='b')
    axs[0].scatter(train.loc[No_Garg_rows,nvar],train.loc[No_Garg_rows,'SalePrice'])

    print(nvar, 'indices > 0', No_Garg_rows[np.where(train.loc[No_Garg_rows, nvar]>0)])
    
    axs[0].tick_params(axis='x', rotation=45)
    axs[0].set_ylabel('SalePrice')
    axs[0].set_xlabel(nvar)
# Out:
# GarageCars indices > 0 []
# GarageArea indices > 0 []

# %%
print(train['Alley'].unique())
train.loc[(train['Alley'].isna()),'Alley']= 'NoAlley'
print(train['Alley'].unique())
# Out:
# [nan 'Grvl' 'Pave']
# ['None' 'Grvl' 'Pave']

# %%
print(train['MasVnrType'].unique())
# looks good
# ohhh i haven't removed these yet
# print('Okay all the MasVnrType = None rows, are MasVnrArea = 0')
# train.loc[train['MasVnrType']=='None','MasVnrArea'].unique()
# Out:
# ['BrkFace' 'None' 'Stone' 'BrkCmn']
# Okay all the MasVnrType = None rows, are MasVnrArea = 0
# array([  0., 288.,   1., 344., 312.])

# %%
print(train['Electrical'].unique())
np.where(train['Electrical'].isna())
print(train.loc[1379,'Electrical'])
# remove row 1379??? electrical information missing
# Out:
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
# nan

# %%
print('FireplaceQu: ', train['FireplaceQu'].unique())
print('Firepaces unique values for the NANs: ', train.loc[train['FireplaceQu'].isna(),'Fireplaces'].unique())
train.loc[(train['FireplaceQu'].isna()),'FireplaceQu']= 'NoFirePlace'
# Out:
# FireplaceQu:  ['NoFirePlace' 'TA' 'Gd' 'Fa' 'Ex' 'Po']
# Firepaces unique values for the NANs:  []

# %%
print('Fence: ', train['Fence'].unique())
train.loc[(train['Fence'].isna()),'Fence']= 'NoFence'
print('Fence: ', train['Fence'].unique())
# Out:
# Fence:  [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# Fence:  ['NoFence' 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']

# %%
print('MiscFeature: ', train['MiscFeature'].unique())
train.loc[(train['MiscFeature'].isna()),'MiscFeature']= 'None'
print('MiscFeature: ', train['MiscFeature'].unique())
# Out:
# MiscFeature:  [nan 'Shed' 'Gar2' 'Othr' 'TenC']
# MiscFeature:  ['None' 'Shed' 'Gar2' 'Othr' 'TenC']

# %% [markdown]
# ### Pool Analysis

# %%
print('PoolQC: ', train['PoolQC'].unique())
train.loc[(train['PoolQC'].isna()),'PoolQC']= 'NoPool'
print('PoolQC: ', train['PoolQC'].unique())
# Out:
# PoolQC:  [nan 'Ex' 'Fa' 'Gd']
# PoolQC:  ['NoPool' 'Ex' 'Fa' 'Gd']

# %%
print('Okay all the PoolArea = 0 rows, are PoolQC = NoPool')
train.loc[train['PoolArea']==0,'PoolQC'].unique()
# Out:
# Okay all the Area = 0 rows, are NoPool
# array(['NoPool'], dtype=object)

# %%
print('Okay all the PoolQC = NoPool rows, are Area = 0')
train.loc[train['PoolQC']=='NoPool','PoolArea'].unique()
# Out:
# Okay all the PoolQC = NoPool rows, are Area = 0
# array([0])

# %% [markdown]
# ## 3C. Separate the input and output variables

# %%
print(numlist)

# %%
# Remove 'SalePrice' from the numlist
numlist.remove('SalePrice')
numlist.remove('Id')
print(numlist)

# %%
print(catlist)

# %%
# catlist_short = ['Neighborhood','ExterQual','KitchenQual']
catlist_short = ['Neighborhood']

# %%
# CONCATENATE!! the numerical and categorical
inputs_vars = numlist + catlist_short
print(inputs_vars)

# %%
## separate the input variables and output variables
PriceFeatures = train[inputs_vars].copy()
Price       = train['SalePrice']

# %%
### separate the input variables and output variables
#PriceFeatures = train[['OverallQual','YearBuilt','YearRemodAdd',
#             'MasVnrArea','MasVnrArea','TotalBsmtSF', 
#             '1stFlrSF','GrLivArea','FullBath',
#             'TotRmsAbvGrd','Fireplaces','GarageYrBlt',
#             'GarageCars','GarageArea','Neighborhood']].copy()
#Price       = train['SalePrice']

# %%
PriceFeatures

# %% [markdown]
# ### Handle Missing Data - Will remove this later, because I plan to handle missing data before this point

# %%
# Generate the boolean flags indicating missing rows and columns
missingRows = PriceFeatures.isnull().any(axis=1)
missingCols = PriceFeatures.isnull().any()
print('The columns with missingness are %s' %(PriceFeatures.columns[missingCols]))
PriceFeatures = PriceFeatures[~missingRows]  # remove rows with missingness
Price = Price[~missingRows]

# %% [markdown]
# ### Dummify

# %%
PriceFeatures.groupby(['Neighborhood']).size().sort_values(ascending=False)

# %%
dummy = pd.get_dummies(PriceFeatures['Neighborhood'], prefix='Neighborhood')
dummy

# %%
dummy.drop('Neighborhood_NAmes', axis=1, inplace=True)

# %%
PriceFeatures = PriceFeatures.drop('Neighborhood', axis=1)  # drop the original Neighborhood feature
PriceFeatures = pd.concat([PriceFeatures, dummy], axis=1) # concat PriceFeatures and dummy horizontally
PriceFeatures.head()

# %% [markdown]
# # Baseline Model: Linear Regression

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    PriceFeatures, Price, test_size=0.2, 
    random_state=0)

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()
lm.fit(X_train, y_train)
residuals = Price - lm.predict(PriceFeatures)
plt.hist(residuals,bins=100);
print('R^2 for train is equal to %.3f' %(lm.score(X_train, y_train)))
print('R^2 for test is equal to %.3f' %(lm.score(X_test, y_test)))
# print('RSS is equal to %.3f' %(np.sum((lm.predict(PriceFeatures) - Price) ** 2)))
# print('The intercept is %.3f' %(lm.intercept_))
# print('The slopes are %s' %(lm.coef_))

# %%
pd.Series(lm.coef_, index=PriceFeatures.columns)

# %%
#print('negative slope column names %s' %(PriceFeatures.columns[lm.coef_<0]))
#print('positive slope column names %s' %(PriceFeatures.columns[lm.coef_>0]))

# %%
plt.plot(lm.predict(PriceFeatures), 
         Price, 'ko')
x = np.linspace(0, 800000, 1000)
y = np.linspace(0, 800000, 1000)
plt.plot(x,y, 'r-')

plt.ylabel('Actual Sale Price')
plt.xlabel('Predicted Sale Price')
plt.xticks(rotation = 45); # Rotates X-Axis Ticks by 45-degrees

# %% [markdown]
# # Model 2: Lasso

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
# Grid Search 
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

skfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=0)
lasso  = Lasso()
params = {
    "alpha": [0, 100, 125, 150]
}

gs = GridSearchCV(lasso, params, scoring = 'r2', cv=skfold)
gs.fit(X_train_scaled, y_train)
gs.cv_results_['mean_test_score']

# %%
gs.best_estimator_

# %%
# gs.best_estimator_.score

# %%
# print('R^2 is equal to %.3f' %(lm.score(PriceFeatures, Price)))

# %%
pd.Series(gs.best_estimator_.coef_, index=PriceFeatures.columns)

# %%
plt.plot(lm.predict(X_train), 
         y_train, 'ko')
plt.plot(gs.best_estimator_.predict(X_train_scaled), # new model
         y_train, 'b*')
x = np.linspace(0, 800000, 1000)
y = np.linspace(0, 800000, 1000)
plt.plot(x,y, 'r-')

plt.ylabel('Actual Sale Price')
plt.xlabel('Predicted Sale Price')
plt.xticks(rotation = 45); # Rotates X-Axis Ticks by 45-degrees

# %%
#lasso  = Lasso()
#lasso.get_params().keys()

# %% [markdown]
# # Model 3: Random Forest

# %% [markdown]
# # Model 4: Gradient Boosting
